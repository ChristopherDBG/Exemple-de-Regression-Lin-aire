# %%
import pandas as pd

menus = pd.read_csv("https://fxjollois.github.io/cours-2022-2023/lp-iot--python-ds/menus_mcdonald.csv")
menus.head()
# Out:
#    Unnamed: 0   Category                              Item    Serving Size  \
# 0           0  Breakfast                      Egg McMuffin  4.8 oz (136 g)
# 1           1  Breakfast                 Egg White Delight  4.8 oz (135 g)
# 2           2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)
# 3           3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)
# 4           4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)
#
#    Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0       300                120       13.0                         20
# 1       250                 70        8.0                         12
# 2       370                200       23.0                         35
# 3       450                250       28.0                         43
# 4       400                210       23.0                         35
#
#    Saturated Fat  Saturated Fat (% Daily Value)  ...  Carbohydrates  \
# ...

# %%
#Décrire les données (distribution des variables, données aberrantes)

menus.describe()
# Out:
#        Unnamed: 0     Calories  Calories from Fat   Total Fat  \
# count  260.000000   260.000000         260.000000  260.000000
# mean   129.500000   368.269231         127.096154   14.165385
# std     75.199734   240.269886         127.875914   14.205998
# min      0.000000     0.000000           0.000000    0.000000
# 25%     64.750000   210.000000          20.000000    2.375000
# 50%    129.500000   340.000000         100.000000   11.000000
# 75%    194.250000   500.000000         200.000000   22.250000
# max    259.000000  1880.000000        1060.000000  118.000000
#
#        Total Fat (% Daily Value)  Saturated Fat  \
# count                 260.000000     260.000000
# mean                   21.815385       6.007692
# std                    21.885199       5.321873
# min                     0.000000       0.000000
# 25%                     3.750000       1.000000
# 50%                    17.000000       5.000000
# 75%                    35.000000      10.000000
# ...

# %%
menus.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Item', 'Serving Size', 'Calories',
#        'Calories from Fat', 'Total Fat', 'Total Fat (% Daily Value)',
#        'Saturated Fat', 'Saturated Fat (% Daily Value)', 'Trans Fat',
#        'Cholesterol', 'Cholesterol (% Daily Value)', 'Sodium',
#        'Sodium (% Daily Value)', 'Carbohydrates',
#        'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrer le dataframe pour n'inclure que les colonnes avec des données numériques
menus_numeric = menus.select_dtypes(include=['float64', 'int64'])

plt.figure(figsize=(30, 40))
sns.boxplot(data=menus_numeric, orient="h")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Exclusion des variables qualitatives
numerical_cols = menus.select_dtypes(include=['float64', 'int64']).columns

# Standardisation des variables numériques
scaler = StandardScaler()
menus_standardized = pd.DataFrame(scaler.fit_transform(menus[numerical_cols]), columns=numerical_cols)

# Tracé des boxplots pour les variables standardisées
plt.figure(figsize=(16, 8))
sns.boxplot(data=menus_standardized, orient="h")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Exclusion des variables qualitatives
numerical_cols = menus.select_dtypes(include=['float64', 'int64']).columns

# Standardisation des variables numériques
scaler = StandardScaler()
menus_standardized = pd.DataFrame(scaler.fit_transform(menus[numerical_cols]), columns=numerical_cols)

# Tracé des boxplots pour les variables standardisées
plt.figure(figsize=(16, 8))
sns.histplot(data=menus_standardized,kde=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Exclusion des variables qualitatives
numerical_cols = menus.select_dtypes(include=['float64', 'int64']).columns

# Standardisation des variables numériques
scaler = StandardScaler()
menus_standardized = pd.DataFrame(scaler.fit_transform(menus[numerical_cols]), columns=numerical_cols)

# Tracé des boxplots pour les variables standardisées pour chaque colonne séparément
for col in numerical_cols:
    plt.figure(figsize=(16, 16))
    sns.histplot(data=menus_standardized[col], kde=True)
    plt.title(f'Histogramme pour {col}')
plt.show()
# Out:
# C:\Users\diele\AppData\Local\Temp\ipykernel_23588\3956637969.py:15: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(16, 16))

# %%
#matrice de corrélation
sns.heatmap(menus_standardized.corr(), center = 0, cmap = "PiYG")
# Out:
# <Axes: >

# %%
menus.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Item', 'Serving Size', 'Calories',
#        'Calories from Fat', 'Total Fat', 'Total Fat (% Daily Value)',
#        'Saturated Fat', 'Saturated Fat (% Daily Value)', 'Trans Fat',
#        'Cholesterol', 'Cholesterol (% Daily Value)', 'Sodium',
#        'Sodium (% Daily Value)', 'Carbohydrates',
#        'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
#nouveau dataframe
# Liste des colonnes à supprimer
cols_to_remove = ['Unnamed: 0','Category','Item','Serving Size','Total Fat','Total Fat (% Daily Value)','Saturated Fat (% Daily Value)','Sodium (% Daily Value)',
                 'Carbohydrates (% Daily Value)','Dietary Fiber (% Daily Value)']  # Remplacez par les noms des colonnes que vous souhaitez supprimer

# Supprimer les colonnes
menu1 = menus.drop(columns=cols_to_remove, axis=1)

# %%
menus_1=menu1
menus_1= menus_1.drop(columns=['Vitamin C (% Daily Value)','Trans Fat'], axis=1)
menus_1.head()
# Out:
#    Calories  Calories from Fat  Saturated Fat  Cholesterol  \
# 0       300                120            5.0          260
# 1       250                 70            3.0           25
# 2       370                200            8.0           45
# 3       450                250           10.0          285
# 4       400                210            8.0           50
#
#    Cholesterol (% Daily Value)  Sodium  Carbohydrates  Dietary Fiber  Sugars  \
# 0                           87     750             31              4       3
# 1                            8     770             30              4       3
# 2                           15     780             29              4       2
# 3                           95     860             30              4       2
# 4                           16     880             30              4       2
#
#    Protein  Vitamin A (% Daily Value)  Calcium (% Daily Value)  \
# 0       17                         10                       25
# ...

# %%
#matrice de corrélation
sns.heatmap(menus_1.corr(), center = 0, cmap = "PiYG")
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import numpy as np

# %%
len(menus_1.columns)
# Out:
# 13

# %%
#Réaliser une ACP
wine_bis = scale(menus_1)
pca = PCA(n_components = 13)
pca.fit(wine_bis)
# Out:
# PCA(n_components=13)

# %%
#Choix du nombre de variables
eig = pandas.DataFrame(
    {
        "Dimension" : ["Dim" + str(x + 1) for x in range(13)], 
        "Valeur propre" : pca.explained_variance_,
        "% variance expliquée" : np.round(pca.explained_variance_ratio_ * 100),
        "% cum. var. expliquée" : np.round(np.cumsum(pca.explained_variance_ratio_) * 100)
    },
    columns = ["Dimension", "Valeur propre", "% variance expliquée", "% cum. var. expliquée"]
)
eig.head(4)
# Out:
#   Dimension  Valeur propre  % variance expliquée  % cum. var. expliquée
# 0      Dim1       6.805794                  52.0                   52.0
# 1      Dim2       2.669610                  20.0                   73.0
# 2      Dim3       1.201279                   9.0                   82.0
# 3      Dim4       0.879742                   7.0                   89.0

# %% [markdown]
# Commentaire: On veut que les deux premières variables permettent d'expliquer 72%  de nos données.

# %%
#variance expliquée par dimension
plt.figure(figsize=(16, 6))
g_eig = sns.barplot(x = "Dimension", 
                        y = "% variance expliquée",
                        palette = ["lightseagreen"],
                        data = eig)
plt.text(12, 100/16, "Seuil")
plt.axhline(y = 100/13, linewidth = .5, color = "dimgray", linestyle = "--")
g_eig.set(ylabel = "Variance expliquée (%)")
g_eig.figure.suptitle("Variance expliquée par dimension")

plt.show()

# %%
#création du nuages de point sur le plan facroriel
#ici on peut faire cette projection par la variable 'catégory'

wine_pca_df = pandas.DataFrame(pca.transform(wine_bis), 
                               columns = ["Dim" + str(i+1) for i in range(13)]) \
                    .assign(Class = menus["Category"])


fig, axes = plt.subplots(figsize = (16, 8))
fig.suptitle("Premier plan factoriel")
axes.axvline(x = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
axes.axhline(y = 0, color = 'lightgray', linestyle = '--', linewidth = 1)

g_pca = sns.scatterplot(x = "Dim1", y = "Dim2", hue = "Class", data = wine_pca_df, 
                            palette = "Set1", s = 100)
g_pca.set(xlabel = "Dimension 1", ylabel = "Dimension 2")

plt.show()

# %%
#cercle de correlation
coordvar = pca.components_.T * np.sqrt(pca.explained_variance_)
coordvar_df = pandas.DataFrame(coordvar, columns=['PC'+str(i+1) for i in range(13)], index=menus_1.columns)
fig, axes = plt.subplots(figsize = (10, 10))
fig.suptitle("Cercle des corrélations")
axes.set_xlim(-1, 1)
axes.set_ylim(-1, 1)
axes.axvline(x = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
axes.axhline(y = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
for j in range(13):
    axes.text(coordvar_df["PC1"][j],coordvar_df["PC2"][j], coordvar_df.index[j], size = 25)
    axes.plot([0,coordvar_df["PC1"][j]], [0,coordvar_df["PC2"][j]], color = "gray", linestyle = 'dashed')
plt.gca().add_artist(plt.Circle((0,0),1,color='blue',fill=False))

plt.show()
